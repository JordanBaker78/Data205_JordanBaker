# %% [markdown]
# <a href="https://colab.research.google.com/github/JordanBaker78/Data205_JordanBaker/blob/main/Capstone_Project_Final.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Data 205 Capstone Project: Exploring NFL Statistics
#
# ##Jordan Baker
# ###Spring 2026
#
# ------------------------------------------------------------------------

# %% [markdown]
# ##Intoduction
# ###Libraries and Datasets
#
# ------------------------------------------------------------------------
#
#
# This project will be utilizing several libraries, including the main libraries such as: Numpy, Pandas, Matplotlib, and Seaborn for visualizations, as well as Sklearn and Stats.models for linear regression tests. The main group of datasets for analysis will be the ‘Stats’ datasets, with the ‘Drives’, ‘Scoring’, and ‘Season’ datasets will be used for extra analysis and added context.

# %% [markdown]
# ##Main Focus/Questions to be answered
# ------------------------------------------------------------------------
# The main focus of this project...
#
# [Update this] My primary focus for this project is to explore trends from season to season, with a focus on the
# last 5 seasons. The datasets I will be using will be the last 5 years of data from each dataset I mentioned
# above. (Each year is its own dataset, so I could be working with up to 20 total individual datasets.) In my
# analysis, I will aim to answer some questions, such as: How has the league changed in 5 years? How have
# the team stats evolved? How have individual player stats evolved? Is there any correlation between a
# change in team stats and player stats? Is there any significant difference in the data from each game across
# the last 5 seasons? Which team or teams have changed the most in the last 5 seasons? What does the
# scoring data have to say about the overall offense and defense of the teams in the league? What are the
# offensive and defensive trends over the last 5 years?

# %%
import pandas as pd
import plotly.graph_objects as go
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
import statsmodels.formula.api as smf
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score

# %% [markdown]
# ##Part 1:Rushing Data
# ------------------------------------------------------------------------
# ### 1a: Team Data

# %% [markdown]
# ###1b: League Data

# %% [markdown]
# ##Part 2: Passing Data
# ------------------------------------------------------------------------
# ###2a: Team Data

# %% [markdown]
# ###2b: League Data

# %% [markdown]
# ##Part 3: Correlation
# ------------------------------------------------------------------------

# %% [markdown]
# ##Conclusion: Final Findings, What's next?
